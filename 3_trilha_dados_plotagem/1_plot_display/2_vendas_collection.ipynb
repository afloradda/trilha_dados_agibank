# %% [markdown]
# # Análise de Correlação Avançada - Exercício Individual

# %% [markdown]
# ---

# %% [markdown]
# ## Bloco 1 - Configuração Inicial
#
# **Setup do Ambiente**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

vendas = pd.read_csv('data/vendas_correlation.csv')
vendas.set_index(vendas['ID_Aleatorio'])

print(f" Dataset carregado: {vendas.shape[0]} linhas × {vendas.shape[1]} colunas")
# Out:
#  Dataset carregado: 200 linhas × 6 colunas

# %% [markdown]
# ---

# %% [markdown]
# ## Bloco 2 - Exploração Estatística Expandida
#
# **Análise Descritiva Aprofundada**

# %%
# Versão expandida (Utilizando claude-sonnet-4):

print("="*50)
print("ANÁLISE EXPLORATÓRIA COMPLETA")
print("="*50)

# Informações gerais
display(vendas.info())
print("\n" + "="*92)

# Estatísticas descritivas
print("Estatísticas Descritivas:")
display(vendas.describe().round(2))
print("\n" + "="*92)
# Out:
# ==================================================
# ANÁLISE EXPLORATÓRIA COMPLETA
# ==================================================
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Vendas (Alvo)        200 non-null    int64
#  1   Temperatura (C)      200 non-null    float64
#  2   Marketing (R$)       200 non-null    float64
#  3   Preco Unitario (R$)  200 non-null    float64
#  4   Chuva (mm)           200 non-null    float64
#  5   ID_Aleatorio         200 non-null    int64
# dtypes: float64(4), int64(2)
# memory usage: 9.5 KB
# None
# ============================================================================================
# Estatísticas Descritivas:
#        Vendas (Alvo)  Temperatura (C)  Marketing (R$)  Preco Unitario (R$)  \
# count         200.00           200.00          200.00               200.00
# mean          197.56            27.10           52.07                 8.53
# std            81.47             7.37           30.73                 2.05
# min            -7.00            15.10            1.08                 5.04
# 25%           140.00            20.70           25.55                 6.83
# 50%           198.00            27.35           52.54                 8.79
# 75%           258.50            33.92           81.12                10.20
# max           389.00            39.70           99.97                11.93
#
#        Chuva (mm)  ID_Aleatorio
# count      200.00        200.00
# mean         4.50       5074.44
# std          4.31       2194.15
# min          0.10       1054.00
# 25%          1.38       3314.50
# 50%          3.15       5092.00
# 75%          6.45       6955.25
# max         23.00       8973.00
# ============================================================================================

# %%
# Verificação de dados faltantes
print("Dados Faltantes:")
missing_data = vendas.isnull().sum()
missing_percent = (missing_data / len(vendas)) * 100
missing_df = pd.DataFrame({
    'Valores Faltantes': missing_data,
    'Percentual (%)': missing_percent.round(2)
})
display(missing_df[missing_df['Valores Faltantes'] > 0])
# Out:
# Dados Faltantes:
# Empty DataFrame
# Columns: [Valores Faltantes, Percentual (%)]
# Index: []

# %%
# Outliers usando IQR
print("\n⚠️ Análise de Outliers (Método IQR):")
for col in vendas.select_dtypes(include=[np.number]).columns:
    Q1 = vendas[col].quantile(0.25)
    Q3 = vendas[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = vendas[(vendas[col] < lower_bound) | (vendas[col] > upper_bound)]
    print(f"  {col}: {len(outliers)} outliers detectados")
# Out:
# ⚠️ Análise de Outliers (Método IQR):
#   Vendas (Alvo): 0 outliers detectados
#   Temperatura (C): 0 outliers detectados
#   Marketing (R$): 0 outliers detectados
#   Preco Unitario (R$): 0 outliers detectados
#   Chuva (mm): 7 outliers detectados
#   ID_Aleatorio: 0 outliers detectados

# %% [markdown]
# ---

# %% [markdown]
# ## Bloco 3 - Análise de Correlação Avançada
#
# **Matriz de Correlação com Insights**

# %%
# Versão inicial (feita individualmente):

correlacao_clima = vendas[['Vendas (Alvo)', 'Temperatura (C)', 'Marketing (R$)']]
matriz_corr_clima = correlacao_clima.corr()

print("="*70)
print(matriz_corr_clima)
print("="*70)
# Out:
# ======================================================================
#                  Vendas (Alvo)  Temperatura (C)  Marketing (R$)
# Vendas (Alvo)         1.000000         0.437119        0.768241
# Temperatura (C)       0.437119         1.000000       -0.045583
# Marketing (R$)        0.768241        -0.045583        1.000000
# ======================================================================

# %%
# Versão expandida (Utilizando claude-sonnet-4):

# Incluir todas as variáveis numéricas relevantes
colunas_numericas = vendas.select_dtypes(include=[np.number]).columns.tolist()
print(f"Variáveis numéricas disponíveis: {colunas_numericas}")

# Análise de correlação completa
correlacao_completa = vendas[colunas_numericas]
matriz_corr_completa = correlacao_completa.corr()

print("="*70)
print(matriz_corr_completa)
print("="*70)
# Out:
# Variáveis numéricas disponíveis: ['Vendas (Alvo)', 'Temperatura (C)', 'Marketing (R$)', 'Preco Unitario (R$)', 'Chuva (mm)', 'ID_Aleatorio']
# ======================================================================
#                      Vendas (Alvo)  Temperatura (C)  Marketing (R$)  \
# Vendas (Alvo)             1.000000         0.437119        0.768241
# Temperatura (C)           0.437119         1.000000       -0.045583
# Marketing (R$)            0.768241        -0.045583        1.000000
# Preco Unitario (R$)      -0.508921        -0.026651       -0.123831
# Chuva (mm)               -0.191877        -0.074051        0.081538
# ID_Aleatorio              0.030587        -0.092864        0.106707
#
#                      Preco Unitario (R$)  Chuva (mm)  ID_Aleatorio
# Vendas (Alvo)                  -0.508921   -0.191877      0.030587
# Temperatura (C)                -0.026651   -0.074051     -0.092864
# Marketing (R$)                 -0.123831    0.081538      0.106707
# Preco Unitario (R$)             1.000000    0.161250     -0.036004
# Chuva (mm)                      0.161250    1.000000      0.090662
# ID_Aleatorio                   -0.036004    0.090662      1.000000
# ======================================================================

# %% [markdown]
# ---

# %% [markdown]
# ## Bloco 4 - Visualização Aprimorada
#
# **Heatmap com Múltiplas Perspectivas**

# %%
# Versão inicial (feita individualmente):

print(("="*20) + " Matriz de COrrelação " + ("="*19))
display(matriz_corr_clima.style.background_gradient(cmap='coolwarm', axis=None).format("{:.2f}"))
# Out:
# ==================== Matriz de COrrelação ===================
# <style type="text/css">
# #T_d5951_row0_col0, #T_d5951_row1_col1, #T_d5951_row2_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_d5951_row0_col1, #T_d5951_row1_col0 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_d5951_row0_col2, #T_d5951_row2_col0 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_d5951_row1_col2, #T_d5951_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d5951">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d5951_level0_col0" class="col_heading level0 col0" >Vendas (Alvo)</th>
#       <th id="T_d5951_level0_col1" class="col_heading level0 col1" >Temperatura (C)</th>
#       <th id="T_d5951_level0_col2" class="col_heading level0 col2" >Marketing (R$)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d5951_level0_row0" class="row_heading level0 row0" >Vendas (Alvo)</th>
#       <td id="T_d5951_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_d5951_row0_col1" class="data row0 col1" >0.44</td>
#       <td id="T_d5951_row0_col2" class="data row0 col2" >0.77</td>
#     </tr>
#     <tr>
#       <th id="T_d5951_level0_row1" class="row_heading level0 row1" >Temperatura (C)</th>
#       <td id="T_d5951_row1_col0" class="data row1 col0" >0.44</td>
#       <td id="T_d5951_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_d5951_row1_col2" class="data row1 col2" >-0.05</td>
#     </tr>
#     <tr>
#       <th id="T_d5951_level0_row2" class="row_heading level0 row2" >Marketing (R$)</th>
#       <td id="T_d5951_row2_col0" class="data row2 col0" >0.77</td>
#       <td id="T_d5951_row2_col1" class="data row2 col1" >-0.05</td>
#       <td id="T_d5951_row2_col2" class="data row2 col2" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Versão expandida (Utilizando claude-sonnet-4):

print("\n Matriz de Correlação - Formato Tabela:")
display(matriz_corr_clima.style
        .background_gradient(cmap='coolwarm', axis=None)
        .format("{:.3f}")
        .set_caption("Correlações entre Vendas, Temperatura em Marketing")
        .set_table_styles([
            {'selector': 'caption', 'props': [('font-size', '16px'), ('font-weight', 'bold')]},
            {'selector': 'th', 'props': [('background-color', "#a700a1"), ('font-weight', 'bold')]}
        ]))
# Out:
#  Matriz de Correlação - Formato Tabela:
# <style type="text/css">
# #T_3f20e caption {
#   font-size: 16px;
#   font-weight: bold;
# }
# #T_3f20e th {
#   background-color: #a700a1;
#   font-weight: bold;
# }
# #T_3f20e_row0_col0, #T_3f20e_row1_col1, #T_3f20e_row2_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_3f20e_row0_col1, #T_3f20e_row1_col0 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_3f20e_row0_col2, #T_3f20e_row2_col0 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_3f20e_row1_col2, #T_3f20e_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_3f20e">
#   <caption>Correlações entre Vendas, Temperatura em Marketing</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3f20e_level0_col0" class="col_heading level0 col0" >Vendas (Alvo)</th>
#       <th id="T_3f20e_level0_col1" class="col_heading level0 col1" >Temperatura (C)</th>
#       <th id="T_3f20e_level0_col2" class="col_heading level0 col2" >Marketing (R$)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3f20e_level0_row0" class="row_heading level0 row0" >Vendas (Alvo)</th>
#       <td id="T_3f20e_row0_col0" class="data row0 col0" >1.000</td>
#       <td id="T_3f20e_row0_col1" class="data row0 col1" >0.437</td>
#       <td id="T_3f20e_row0_col2" class="data row0 col2" >0.768</td>
#     </tr>
#     <tr>
#       <th id="T_3f20e_level0_row1" class="row_heading level0 row1" >Temperatura (C)</th>
#       <td id="T_3f20e_row1_col0" class="data row1 col0" >0.437</td>
#       <td id="T_3f20e_row1_col1" class="data row1 col1" >1.000</td>
#       <td id="T_3f20e_row1_col2" class="data row1 col2" >-0.046</td>
#     </tr>
#     <tr>
#       <th id="T_3f20e_level0_row2" class="row_heading level0 row2" >Marketing (R$)</th>
#       <td id="T_3f20e_row2_col0" class="data row2 col0" >0.768</td>
#       <td id="T_3f20e_row2_col1" class="data row2 col1" >-0.046</td>
#       <td id="T_3f20e_row2_col2" class="data row2 col2" >1.000</td>
#     </tr>
#   </tbody>
# </table>

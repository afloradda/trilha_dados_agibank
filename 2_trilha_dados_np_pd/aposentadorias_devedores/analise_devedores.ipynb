# %% [markdown]
# # Análise Cruzada de Dados - Aposentados vs Devedores

# %% [markdown]
# ---

# %% [markdown]
# ## Bloco 2 - Importação do Dataset de Devedores
#
# **Exploração Inicial dos Dados**

# %%
import pandas as pd
import numpy as np

devedores_df_original = pd.read_csv('data/devedores.csv', sep=';', encoding='latin-1')
devedores_df_original.head()
# Out:
#   DATA DE GERAÇÃO    CPF/CNPJ DEVEDOR   TIPO DE PESSOA TIPO DO DEVEDOR  \
# 0      04/12/2023  68.559.467/0001-00  Pessoa jurídica       Principal
# 1      04/12/2023      XXX.160.007-XX    Pessoa física  Corresponsável
# 2      04/12/2023  81.545.550/0001-98  Pessoa jurídica       Principal
# 3      04/12/2023  59.960.658/0001-98  Pessoa jurídica       Principal
# 4      04/12/2023  03.887.547/0001-49  Pessoa jurídica       Principal
#
#                                      NOME DO DEVEDOR  \
# 0                   Gap Sistemas de Comunicacao LTDA
# 1                         Jose Carlos da Silva Gomes
# 2  Araranguaense Administradora de Consorcios S C...
# 3                                Falavina & Cia LTDA
# 4           Quanto Mais Importacao e Exportacao LTDA
#
#   NÚMERO DO TERMO DE INSCRIÇÃO DATA DA INSCRIÇÃO SEQUENCIAL DO CRÉDITO  \
# 0                    0186/2005        23/11/2005        CR2013/0000003
# 1                    0186/2005        23/11/2005        CR2013/0000003
# ...

# %%
devedores_df_original.describe()   # Estatísticas descritivas
# Out:
#        DATA DE GERAÇÃO CPF/CNPJ DEVEDOR   TIPO DE PESSOA TIPO DO DEVEDOR  \
# count             2576             2568             2568            2576
# unique               1             2238                2               2
# top         04/12/2023   XXX.827.945-XX  Pessoa jurídica       Principal
# freq              2576               17             1669            2315
#
#                                   NOME DO DEVEDOR  \
# count                                        2576
# unique                                       2241
# top     Stephane Joseph Ghislain Mery de Montigny
# freq                                           17
#
#        NÚMERO DO TERMO DE INSCRIÇÃO DATA DA INSCRIÇÃO SEQUENCIAL DO CRÉDITO  \
# count                          2576              2576                  2576
# unique                         2306              1398                  2315
# top                       0002/1984        10/06/2003        CR2013/0005435
# ...

# %%
devedores_df_original.count()      # Contagem de valores não-nulos
# Out:
# DATA DE GERAÇÃO                 2576
# CPF/CNPJ DEVEDOR                2568
# TIPO DE PESSOA                  2568
# TIPO DO DEVEDOR                 2576
# NOME DO DEVEDOR                 2576
# NÚMERO DO TERMO DE INSCRIÇÃO    2576
# DATA DA INSCRIÇÃO               2576
# SEQUENCIAL DO CRÉDITO           2576
# SITUAÇÃO DO CRÉDITO             2576
# MOTIVO DA SUSPENSÃO              225
# ORIGEM                          2576
# CREDOR                          2576
# SALDO DEVEDOR SEM HONORÁRIOS    2576
# OBSERVAÇÃO                        13
# dtype: int64

# %%
devedores_df_original['TIPO DE PESSOA'].unique()  # Valores únicos
# Out:
# array(['Pessoa jurídica', 'Pessoa física', nan], dtype=object)

# %% [markdown]
# Análise exploratória sistemática:
#
# - `.head()`: Estrutura e formato dos dados
#
# - `.describe()`: Distribuições numéricas
#
# - `.count()`: Identificar colunas com dados faltantes
#
# - `.unique()`: Categorias disponíveis (PF/PJ)

# %% [markdown]
# 💡 Objetivo: Compreender qualidade e estrutura antes da análise.

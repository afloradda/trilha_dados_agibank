# %% [markdown]
# # Análise Cruzada de Dados - Aposentados vs Devedores

# %% [markdown]
# ---

# %% [markdown]
# ## Bloco 1 - Importação do Dataset de Aposentadorias
#
# **Carregamento com Parâmetros Específicos**

# %%
import pandas as pd
import numpy as np

aposentadorias_df_original = pd.read_csv('data/aposentadorias.csv', sep=';', encoding='latin-1', skiprows=2)
aposentadorias_df_original.head()
# Out:
#                            Nome             CPF Situaï¿½ï¿½o Vï¿½nculo  \
# 0           ABADIA MARCIA CUNHA  ***.161.491-**             Aposentado
# 1  ABDIAS CASSIO MARROCOS GOMES  ***.297.631-**             Aposentado
# 2    ABDIEL ANDRIOLO DE ANDRADE  ***.895.388-**             Aposentado
# 3        ABDON LOPES DE MENESES  ***.983.931-**             Aposentado
# 4            ABEL ALFREDO FILHO  ***.347.385-**             Aposentado
#
#   Matrï¿½cula   UORG                ï¿½rgï¿½o       ï¿½rgï¿½o Superior  \
# 0    000*****  25201  BANCO CENTRAL DO BRASIL  BANCO CENTRAL DO BRASIL
# 1    000*****  25201  BANCO CENTRAL DO BRASIL  BANCO CENTRAL DO BRASIL
# 2    000*****  25201  BANCO CENTRAL DO BRASIL  BANCO CENTRAL DO BRASIL
# 3    000*****  25201  BANCO CENTRAL DO BRASIL  BANCO CENTRAL DO BRASIL
# 4    000*****  25201  BANCO CENTRAL DO BRASIL  BANCO CENTRAL DO BRASIL
#
#     Classe Padrï¿½o  Referï¿½ncia  Nï¿½vel Regime Jurï¿½dico  \
# ...

# %% [markdown]
# Parâmetros importantes:
#
# - `sep=';'`: Separador ponto-e-vírgula (comum em dados brasileiros)
#
# - `encoding='latin-1'`: Codificação para caracteres especiais (acentos)
#
# - `skiprows=2`: Pula primeiras 2 linhas (cabeçalhos ou metadados)

# %% [markdown]
# 💡 Dica: Arquivos governamentais brasileiros frequentemente usam `;` e `latin-1`.
